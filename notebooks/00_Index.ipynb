# %% [markdown]
# # JupyterLite Geospatial Analyses and Maps
#
# This index links to 90 map-first notebooks. Each notebook includes several maps, local datasets, synthetic shapefiles, an original teaching image, and a short layer-stack video clip.
#
# | No. | Symbol | Element | Category | Notebook |
# |---:|---|---|---|---|
# | 1 | VC | Vector Conversion | Vector Analysis and Conversion | [01_VC_vector-conversion.ipynb](01_VC_vector-conversion.ipynb) |
# | 2 | EX | Extract | Vector Analysis and Conversion | [02_EX_extract.ipynb](02_EX_extract.ipynb) |
# | 3 | OV | Overlay | Vector Analysis and Conversion | [03_OV_overlay.ipynb](03_OV_overlay.ipynb) |
# | 4 | PX | Proximity | Vector Analysis and Conversion | [04_PX_proximity.ipynb](04_PX_proximity.ipynb) |
# | 5 | SJ | Spatial Join | Vector Analysis and Conversion | [05_SJ_spatial-join.ipynb](05_SJ_spatial-join.ipynb) |
# | 6 | PD | Plot Diagrams | Vector Analysis and Conversion | [06_PD_plot-diagrams.ipynb](06_PD_plot-diagrams.ipynb) |
# | 7 | GS | Geometry Shape | Vector Analysis and Conversion | [07_GS_geometry-shape.ipynb](07_GS_geometry-shape.ipynb) |
# | 8 | TB | Table Tools | Tables | [08_TB_table-tools.ipynb](08_TB_table-tools.ipynb) |
# | 9 | XY | Add XY Coordinates | Tables | [09_XY_add-xy-coordinates.ipynb](09_XY_add-xy-coordinates.ipynb) |
# | 10 | CG | Calculate Geometry | Tables | [10_CG_calculate-geometry.ipynb](10_CG_calculate-geometry.ipynb) |
# | 11 | JT | Join Table | Tables | [11_JT_join-table.ipynb](11_JT_join-table.ipynb) |
# | 12 | RL | Relate | Tables | [12_RL_relate.ipynb](12_RL_relate.ipynb) |
# | 13 | ST | Statistics | Tables | [13_ST_statistics.ipynb](13_ST_statistics.ipynb) |
# | 14 | ED | Editing | Editing and Cartography | [14_ED_editing.ipynb](14_ED_editing.ipynb) |
# | 15 | CF | Conflation | Editing and Cartography | [15_CF_conflation.ipynb](15_CF_conflation.ipynb) |
# | 16 | GI | Grid Index | Editing and Cartography | [16_GI_grid-index.ipynb](16_GI_grid-index.ipynb) |
# | 17 | CA | Cartographic | Editing and Cartography | [17_CA_cartographic.ipynb](17_CA_cartographic.ipynb) |
# | 18 | 3D | 3D Analysis | 3D Analysis | [18_3D_3d-analysis.ipynb](18_3D_3d-analysis.ipynb) |
# | 19 | LS | Line of Sight Visibility | 3D Analysis | [19_LS_line-of-sight-visibility.ipynb](19_LS_line-of-sight-visibility.ipynb) |
# | 20 | VS | Volume | 3D Analysis | [20_VS_volume.ipynb](20_VS_volume.ipynb) |
# | 21 | VW | Viewshed | 3D Analysis | [21_VW_viewshed.ipynb](21_VW_viewshed.ipynb) |
# | 22 | SL | Skyline | 3D Analysis | [22_SL_skyline.ipynb](22_SL_skyline.ipynb) |
# | 23 | SC | Space-time Cubes | 3D Analysis | [23_SC_space-time-cubes.ipynb](23_SC_space-time-cubes.ipynb) |
# | 24 | RT | Route | Network Analysis | [24_RT_route.ipynb](24_RT_route.ipynb) |
# | 25 | DR | Directions | Network Analysis | [25_DR_directions.ipynb](25_DR_directions.ipynb) |
# | 26 | OS | Optimal Site | Network Analysis | [26_OS_optimal-site.ipynb](26_OS_optimal-site.ipynb) |
# | 27 | CV | Coverage | Network Analysis | [27_CV_coverage.ipynb](27_CV_coverage.ipynb) |
# | 28 | CM | OD Cost Matrix | Network Analysis | [28_CM_od-cost-matrix.ipynb](28_CM_od-cost-matrix.ipynb) |
# | 29 | HM | Huff Model | Network Analysis | [29_HM_huff-model.ipynb](29_HM_huff-model.ipynb) |
# | 30 | DM | Data Management | Data Management | [30_DM_data-management.ipynb](30_DM_data-management.ipynb) |
# | 31 | PJ | Projections | Data Management | [31_PJ_projections.ipynb](31_PJ_projections.ipynb) |
# | 32 | GV | Generalize Vector | Data Management | [32_GV_generalize-vector.ipynb](32_GV_generalize-vector.ipynb) |
# | 33 | AD | Address Geocoding | Data Management | [33_AD_address-geocoding.ipynb](33_AD_address-geocoding.ipynb) |
# | 34 | TP | Topology | Data Management | [34_TP_topology.ipynb](34_TP_topology.ipynb) |
# | 35 | LR | Linear Referencing | Data Management | [35_LR_linear-referencing.ipynb](35_LR_linear-referencing.ipynb) |
# | 36 | SA | Spatial Adjustment | Data Management | [36_SA_spatial-adjustment.ipynb](36_SA_spatial-adjustment.ipynb) |
# | 37 | GE | GeoEnrich | Data Management | [37_GE_geoenrich.ipynb](37_GE_geoenrich.ipynb) |
# | 38 | SP | Sampling | Data Management | [38_SP_sampling.ipynb](38_SP_sampling.ipynb) |
# | 39 | GT | Geotagging | Data Management | [39_GT_geotagging.ipynb](39_GT_geotagging.ipynb) |
# | 40 | PF | Parcel Fabric | Data Management | [40_PF_parcel-fabric.ipynb](40_PF_parcel-fabric.ipynb) |
# | 41 | AT | Attachments | Data Management | [41_AT_attachments.ipynb](41_AT_attachments.ipynb) |
# | 42 | FMV | Full Motion Video | Data Management | [42_FMV_full-motion-video.ipynb](42_FMV_full-motion-video.ipynb) |
# | 43 | CO | COGO | Data Management | [43_CO_cogo.ipynb](43_CO_cogo.ipynb) |
# | 44 | PC | Point Cloud | Data Management | [44_PC_point-cloud.ipynb](44_PC_point-cloud.ipynb) |
# | 45 | WS | Web Service | Data Management | [45_WS_web-service.ipynb](45_WS_web-service.ipynb) |
# | 46 | TIN | TIN | Data Management | [46_TIN_tin.ipynb](46_TIN_tin.ipynb) |
# | 47 | IM | Indoor Mapping | Data Management | [47_IM_indoor-mapping.ipynb](47_IM_indoor-mapping.ipynb) |
# | 48 | TM | Temporal | Data Management | [48_TM_temporal.ipynb](48_TM_temporal.ipynb) |
# | 49 | TR | Real-time Tracking | Data Management | [49_TR_real-time-tracking.ipynb](49_TR_real-time-tracking.ipynb) |
# | 50 | BD | Big Data | Emerging Technology | [50_BD_big-data.ipynb](50_BD_big-data.ipynb) |
# | 51 | ML | Machine Learning | Emerging Technology | [51_ML_machine-learning.ipynb](51_ML_machine-learning.ipynb) |
# | 52 | DE | Data Engineering | Emerging Technology | [52_DE_data-engineering.ipynb](52_DE_data-engineering.ipynb) |
# | 53 | IOT | IoT | Emerging Technology | [53_IOT_iot.ipynb](53_IOT_iot.ipynb) |
# | 54 | AS | Agent-based Simulation and Modeling | Emerging Technology | [54_AS_agent-based-simulation-and-modeling.ipynb](54_AS_agent-based-simulation-and-modeling.ipynb) |
# | 55 | VR | Virtual Reality | Emerging Technology | [55_VR_virtual-reality.ipynb](55_VR_virtual-reality.ipynb) |
# | 56 | AR | Augmented Reality | Emerging Technology | [56_AR_augmented-reality.ipynb](56_AR_augmented-reality.ipynb) |
# | 57 | GR | Georeferencing | Raster Data Management | [57_GR_georeferencing.ipynb](57_GR_georeferencing.ipynb) |
# | 58 | MO | Mosaic | Raster Data Management | [58_MO_mosaic.ipynb](58_MO_mosaic.ipynb) |
# | 59 | RC | Raster Creation | Raster Data Management | [59_RC_raster-creation.ipynb](59_RC_raster-creation.ipynb) |
# | 60 | AL | Spatial Autocorrelation | Raster Data Management | [60_AL_spatial-autocorrelation.ipynb](60_AL_spatial-autocorrelation.ipynb) |
# | 61 | RG | Generalization | Raster Data Management | [61_RG_generalization.ipynb](61_RG_generalization.ipynb) |
# | 62 | MD | Multidimensional | Raster Data Management | [62_MD_multidimensional.ipynb](62_MD_multidimensional.ipynb) |
# | 63 | RS | Resample | Raster Data Management | [63_RS_resample.ipynb](63_RS_resample.ipynb) |
# | 64 | PA | Raster Painting | Raster Data Management | [64_PA_raster-painting.ipynb](64_PA_raster-painting.ipynb) |
# | 65 | RA | Raster Analysis | Raster Analysis | [65_RA_raster-analysis.ipynb](65_RA_raster-analysis.ipynb) |
# | 66 | MA | Map Algebra | Raster Analysis | [66_MA_map-algebra.ipynb](66_MA_map-algebra.ipynb) |
# | 67 | CN | Contours | Raster Analysis | [67_CN_contours.ipynb](67_CN_contours.ipynb) |
# | 68 | ZS | Zonal Statistics | Raster Analysis | [68_ZS_zonal-statistics.ipynb](68_ZS_zonal-statistics.ipynb) |
# | 69 | CP | Cost Path | Raster Analysis | [69_CP_cost-path.ipynb](69_CP_cost-path.ipynb) |
# | 70 | RP | Raster Processing | Raster Analysis | [70_RP_raster-processing.ipynb](70_RP_raster-processing.ipynb) |
# | 71 | RE | Spatial Regression | Raster Analysis | [71_RE_spatial-regression.ipynb](71_RE_spatial-regression.ipynb) |
# | 72 | TA | Terrain Analysis | Raster Analysis | [72_TA_terrain-analysis.ipynb](72_TA_terrain-analysis.ipynb) |
# | 73 | MF | Math Function | Raster Analysis | [73_MF_math-function.ipynb](73_MF_math-function.ipynb) |
# | 74 | SU | Suitability | Raster Analysis | [74_SU_suitability.ipynb](74_SU_suitability.ipynb) |
# | 75 | CON | Conditional | Raster Analysis | [75_CON_conditional.ipynb](75_CON_conditional.ipynb) |
# | 76 | BA | Band Index | Remote Sensing | [76_BA_band-index.ipynb](76_BA_band-index.ipynb) |
# | 77 | IS | Image Stretching | Remote Sensing | [77_IS_image-stretching.ipynb](77_IS_image-stretching.ipynb) |
# | 78 | IC | Image Classification | Remote Sensing | [78_IC_image-classification.ipynb](78_IC_image-classification.ipynb) |
# | 79 | CB | Composite Bands | Remote Sensing | [79_CB_composite-bands.ipynb](79_CB_composite-bands.ipynb) |
# | 80 | PS | Pansharpening | Remote Sensing | [80_PS_pansharpening.ipynb](80_PS_pansharpening.ipynb) |
# | 81 | AC | Atmosphere Correction | Remote Sensing | [81_AC_atmosphere-correction.ipynb](81_AC_atmosphere-correction.ipynb) |
# | 82 | SG | Segmentation | Remote Sensing | [82_SG_segmentation.ipynb](82_SG_segmentation.ipynb) |
# | 83 | DN | Data Mining | Remote Sensing | [83_DN_data-mining.ipynb](83_DN_data-mining.ipynb) |
# | 84 | ME | Mensuration | Remote Sensing | [84_ME_mensuration.ipynb](84_ME_mensuration.ipynb) |
# | 85 | PH | Photogrammetry | Remote Sensing | [85_PH_photogrammetry.ipynb](85_PH_photogrammetry.ipynb) |
# | 86 | OB | Oblique | Remote Sensing | [86_OB_oblique.ipynb](86_OB_oblique.ipynb) |
# | 87 | RD | Radar | Remote Sensing | [87_RD_radar.ipynb](87_RD_radar.ipynb) |
# | 88 | IP | Interpolation | Interpolation | [88_IP_interpolation.ipynb](88_IP_interpolation.ipynb) |
# | 89 | KR | Kriging | Interpolation | [89_KR_kriging.ipynb](89_KR_kriging.ipynb) |
# | 90 | KD | Kernel Density | Interpolation | [90_KD_kernel-density.ipynb](90_KD_kernel-density.ipynb) |

# %%
import pandas as pd
catalog = pd.read_csv('../data/admin_boundaries_attributes.csv')
display(catalog.head())
